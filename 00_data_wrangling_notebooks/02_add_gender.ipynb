# %% [markdown]
# # 02 Add Gender

# %%
# time routine
import time
start_time = time.time()

# import library
import pandas as pd
import re

# %%
# %%time
# import working df
df = pd.read_csv('./data/01_first_clean.csv', header=0, index_col=False)
# Out:
# Wall time: 2.83 s

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169285 entries, 0 to 169284
# Data columns (total 19 columns):
# f_dir        169285 non-null object
# m_id         169285 non-null object
# m_date       169285 non-null object
# m_from       169285 non-null object
# m_to         163413 non-null object
# m_cc         52714 non-null object
# m_bcc        50250 non-null object
# m_subj       162429 non-null object
# mime_vers    169285 non-null float64
# cont_type    169285 non-null object
# encode       169285 non-null object
# x_from       169285 non-null object
# x_to         164697 non-null object
# x_cc         50633 non-null object
# x_bcc        131 non-null object
# x_fold       169285 non-null object
# x_orig       169285 non-null object
# x_fname      167315 non-null object
# m_body       169285 non-null object
# dtypes: float64(1), object(18)
# memory usage: 24.5+ MB

# %%
# total email body chars (for process tracking)
start_chars = df.m_body.apply(len).sum()

print('Total Characters Across All Email Bodies in Corpus: {}.'.format(start_chars))
# Out:
# Total Characters Across All Email Bodies in Corpus: 135952755.

# %% [markdown]
# ### Separate Columns of Interest (Emails, Internal From Field)

# %%
# take out columns for work
fn = df[['m_from', 'x_from']].copy()

# drop duplicates based on email address
fn = fn.drop_duplicates(subset='m_from')

# reset index for the new df
fn = fn.reset_index(drop=True)

# make both columns lowercase
fn.m_from = fn.m_from.str.lower()
fn.x_from = fn.x_from.str.lower()

# %%
# show example of m_from
fn.head()
# Out:
#                        m_from                     x_from
# 0     phillip.allen@enron.com            phillip k allen
# 1        ina.rangel@enron.com                 ina rangel
# 2   critical.notice@enron.com  critical.notice@enron.com
# 3  rebecca.cantrell@enron.com         rebecca w cantrell
# 4      paul.kaufman@enron.com               paul kaufman

# %%
def clean_m_from(s):
    """Use this to recover names from the email addresses
       with regular expression captures. 8 cases are outlined
       below for capture. A final case (ZZ) wipes the cell.
       
       Wiped cell will be used to consider value fills from
       strings recovered from the X-From column."""
    #
    # cleans email addresses for the following cases, returning a string to place in a subsequent (name) column.
    # the following notation is used to explain cases:
    #     fname = first name
    #     lname = last name
    #     mname = middle name
    #     init = initial
    #     ffname = another word considered with first name
    #     scotts = name string contains an apostrophe
    #
    # CASE 01: fname'.lname'@enron.com (fname lname)
    # CASE 02: string@enron.com (string)
    # CASE 03: finit..lname@enron.com or finit.lname@enron.com (finit lname)
    # CASE 04: fname.minit.lname@enron.com (fname lname)
    # CASE 05: fname-ffname.lname@enron.com (fname-ffname lname)
    # CASE 06: fname.lname.enronxgate@enron.com (fname lname)
    # CASE 07: fname_lname@enron.com (fname lname)
    # CASE 08: fname.lname-llname@enron.com (fname lname-llname)
    # CASE ZZ [CREATE NULL]: @enron.com ('')
    # 

    try:

        # CASE 01
        p = '^([A-Za-z\']+)[.]([A-Za-z\']+)@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)
                
        # CASE 02
        p = '^([A-Za-z]+)@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]) # (string)
                    
        # CASE 03
        p = '^([A-Za-z])[.]{1,2}([A-Za-z]+)@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (finit lname)

        # CASE 04
        p = '^([A-Za-z]+)[.][A-Za-z][.]([A-Za-z]+)@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)
            
        # CASE 05
        p = '^([A-Za-z]+[-][A-Za-z]+)[.]([A-Za-z]+)@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname-ffname lname)
            
        # CASE 06
        p = '^([A-Za-z]+)[.]([A-Za-z]+).enronxgate@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)
        
        # CASE 07
        p = '^([A-Za-z\']+)[_]([A-Za-z\']+)@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)
        
        # CASE 08
        p = '^([A-Za-z]+)[.]([A-Za-z]+[-][A-Za-z]+)@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)

        # CASE R02
        p = '^[A-Za-z] [A-Za-z\'-]+$'
        if re.search(p, s):
            s = ''

        # CASE R01
        buzz_words = ['team', 'technology', 'security', 'enron', 'chairman', 'office', 'announcement', 'wizard', 'notice', 'address', 'hr taylor', 'coo jeff', 'infrastructure', 'ubsw', 'europe',
                      'human', 'resources', 'connection', 'ibuyit', 'users', 'livelink', 'registrar', 'global', 'business', 'compensation', 'executive', 'risk', 'analytics', 'daemon', 'information',
                      'management', 'helpdesk', 'project', 'sunrise', 'oncall', 'credit', 'union', 'notification', 'central', 'communication', 'center', 'parking', 'transportation', 'international',
                      'diversity', 'survey', 'automation', 'document', 'exec', 'iscinfra', 'public', 'relations', 'controls', 'exchange', 'cms router', 'hotline', 'admin', 'pr id', 'expertfinder',
                      'notes', 'the buzz', 'gpg dss', 'xi xi', 'enw piper', 'institute', 'agent', 'tarrif']
                      
        for word in buzz_words:
            if re.search(word, s):
                s = ''
        
        # CASE ZZ
        p = '^[A-Za-z\'-]+ [A-Za-z\'-]+$'
        if re.search(p, s):
            s
        else:
            s = ''

        return(s)
    
    except:
        
        print('EXCEPTION RETURN: ' + s)
        return(s)

# %% [markdown]
# ### Parse Names from Email Addresses

# %%
# run custom function to create a new column
fn['m_from_cleaned'] = fn.m_from.apply(clean_m_from)

# change column order
fn = fn[['m_from', 'm_from_cleaned', 'x_from']]

# check head
fn.head()
# Out:
#                        m_from    m_from_cleaned                     x_from
# 0     phillip.allen@enron.com     phillip allen            phillip k allen
# 1        ina.rangel@enron.com        ina rangel                 ina rangel
# 2   critical.notice@enron.com                    critical.notice@enron.com
# 3  rebecca.cantrell@enron.com  rebecca cantrell         rebecca w cantrell
# 4      paul.kaufman@enron.com      paul kaufman               paul kaufman

# %%
def clean_x_from(s):
    """Use this to recover names from the X-From column
       with regular expression captures. [ ] cases are outlined
       below for capture. A final case (ZZ) wipes the cell.
       
       Wiped cell will be used to match any possible fills between
       m_from and x_from."""
    #
    # cleans email addresses for the following cases, returning a string to place in a subsequent (name) column.
    # the following notation is used to explain cases:
    #     fname = first name
    #     lname = last name
    #     mname = middle name
    #     init = initial
    #     ffname = another word considered with first name
    #     scotts = name string contains an apostrophe
    #
    # CASE 01: 
    # CASE 02: 
    # CASE 03: 
    # CASE 04: 
    # CASE 05: 
    # CASE 06: 
    # CASE 07: 
    # CASE 08: 
    # CASE ZZ [CREATE NULL]: @enron.com ('')
    # 

    try:
        
        # CASE 01
        p = '^([A-Za-z]+) ([A-Za-z]+)$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)

        # CASE 03
        p = '^([A-Za-z]+), ([A-Za-z]+) [A-Za-z][.] {1,2}<.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[2]+' '+s[1]) # (fname lname)    
            
        # CASE 02
        p = '^([A-Za-z\'-]+), ([A-Za-z\'-]+) <.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[2]+' '+s[1]) # (fname lname)
            
            # removes 'team.' subsets of this pattern
            if re.search('team', s):
                s = ''

        # CASE 14
        p = '^[A-Za-z] ([A-Za-z]+) ([A-Za-z]+) <.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)                
                
        # CASE 04
        p = '^([A-Za-z]+) [A-Za-z] ([A-Za-z]+) <.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)

        # CASE 05
        p = '^([A-Za-z]+) ([A-Za-z]+) <.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)
            
        # CASE 06
        p = '^([A-Za-z]+) [A-Za-z]{2,} ([A-Za-z]+) <.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)

        # CASE 13
        p = '^[A-Za-z] ([A-Za-z]+) ([A-Za-z]+)$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)
            
        # CASE 07
        p = '^([A-Za-z]+) [A-Za-z]+ ([A-Za-z]+)$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)
        
        # CASE 08
        p = '^([A-Za-z]+), ([A-Za-z]+) [A-Za-z]+ {1,2}<.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[2]+' '+s[1]) # (fname lname)
            
        # CASE 09
        p = '^([A-Za-z]+), ([A-Za-z]+)$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[2]+' '+s[1]) # (fname lname)
            
        # CASE 10
        p = '^([A-Za-z]+) [A-Za-z]+., ([A-Za-z]+) <.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[2]+' '+s[1]) # (fname lname)
            
        # CASE 11
        p = '^([A-Za-z]+) [A-Za-z]+[.], ([A-Za-z]+) [A-Za-z][.] <.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[2]+' '+s[1]) # (fname lname)

        # CASE 12
        p = '^([A-Za-z]+) [A-Za-z]+[.], ([A-Za-z]+)[A-Za-z .]{0,3}$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[2]+' '+s[1]) # (fname lname)

        # CASE R02
        p = '^[A-Za-z] [A-Za-z\'-]+$'
        if re.search(p, s):
            s = ''

        # CASE R01
        buzz_words = ['team', 'technology', 'security', 'enron', 'chairman', 'office', 'announcement', 'wizard', 'notice', 'address', 'hr taylor', 'coo jeff', 'infrastructure', 'ubsw', 'europe',
                      'human', 'resources', 'connection', 'ibuyit', 'users', 'livelink', 'registrar', 'global', 'business', 'compensation', 'executive', 'risk', 'analytics', 'daemon', 'information',
                      'management', 'helpdesk', 'project', 'sunrise', 'oncall', 'credit', 'union', 'notification', 'central', 'communication', 'center', 'parking', 'transportation', 'international',
                      'diversity', 'survey', 'automation', 'document', 'exec', 'iscinfra', 'public', 'relations', 'controls', 'exchange', 'cms router', 'hotline', 'admin', 'pr id', 'expertfinder',
                      'notes', 'the buzz', 'gpg dss', 'xi xi', 'enw piper', 'institute', 'agent', 'tarrif']
                      
        for word in buzz_words:
            if re.search(word, s):
                s = ''
        
        # CASE ZZ
        p = '^[A-Za-z\'-]+ [A-Za-z\'-]+$'
        if re.search(p, s):
            s
        else:
            s = ''
        
        return(s)
    
    except:
        
        print('EXCEPTION RETURN: ' + s.group())
        return(s)

# %% [markdown]
# ### Parse Names from X-From Field

# %%
# x_from
fn['x_from_cleaned'] = fn.x_from.apply(clean_x_from)

# peek results
fn.head()
# Out:
#                        m_from    m_from_cleaned                     x_from  \
# 0     phillip.allen@enron.com     phillip allen            phillip k allen
# 1        ina.rangel@enron.com        ina rangel                 ina rangel
# 2   critical.notice@enron.com                    critical.notice@enron.com
# 3  rebecca.cantrell@enron.com  rebecca cantrell         rebecca w cantrell
# 4      paul.kaufman@enron.com      paul kaufman               paul kaufman
#
#      x_from_cleaned
# 0     phillip allen
# 1        ina rangel
# 2
# 3  rebecca cantrell
# 4      paul kaufman

# %% [markdown]
# ### Remove Non-Names

# %%
# condition to catch rows where both clean columns are blank
cond = (fn.m_from_cleaned == '') & (fn.x_from_cleaned == '')

# copy new df of non-condition return
cd = fn[~cond].copy()

# %% [markdown]
#     # fill m_from_cleaned empty values with the value from x_from_cleaned
#     cd.loc[cd['m_from_cleaned'] == '', 'm_from_cleaned'] = cd['x_from_cleaned']
#
#     # fill x_from_cleaned empty values with the value from m_from_cleaned
#     cd.loc[cd['x_from_cleaned'] == '', 'x_from_cleaned'] = cd['m_from_cleaned']

# %%
# create a capture column for the final fname lname
cd['clean_name'] = cd['x_from_cleaned']

# fill blanks with other column returns
cd.loc[cd['clean_name'] == '', 'clean_name'] = cd['m_from_cleaned']

# %% [markdown]
# ### Evaluate Conflicts Between Parses

# %%
# return differences between the two parsed values if they both returned a value
makin_picks = cd[(cd.m_from_cleaned != cd.x_from_cleaned) & (cd.m_from_cleaned != '') & (cd.x_from_cleaned != '')]

# manually review mismatches
print(len(makin_picks))
makin_picks
# Out:
# 32
#                           m_from    m_from_cleaned  \
# 168     buckner.thomas@enron.com    buckner thomas
# 220          jae.black@enron.com         jae black
# 338        pinto.leite@enron.com       pinto leite
# 1061        dana.davis@enron.com        dana davis
# 1096        kay.miller@enron.com        kay miller
# 1113         ann.foret@enron.com         ann foret
# 1553        ann.matson@enron.com        ann matson
# 1570          ann.hill@enron.com          ann hill
# 1628       marie.allex@enron.com       marie allex
# 2296     nell.browning@enron.com     nell browning
# 2577        ann.chance@enron.com        ann chance
# 3388        ann.murphy@enron.com        ann murphy
# 3575    lynn.schaffart@enron.com    lynn schaffart
# 3824        griff.gray@enron.com        griff gray
# 3826       pham.arnold@enron.com       pham arnold
# 3827       marie.smith@enron.com       marie smith
# 4391   melvin.anderson@enron.com   melvin anderson
# 4409         kay.moore@enron.com         kay moore
# 4659      thomas.moore@enron.com      thomas moore
# 4678  enrique.zambrano@enron.com  enrique zambrano
# 4736          jo.allen@enron.com          jo allen
# 4820        paul.lewis@enron.com        paul lewis
# 4914      marie.taylor@enron.com      marie taylor
# 5035        joe.hunter@enron.com        joe hunter
# 5039      dan.arellano@enron.com      dan arellano
# 5144   maria.hernandez@enron.com   maria hernandez
# 5152  theresa.franklin@enron.com  theresa franklin
# 5256        jo.johnson@enron.com        jo johnson
# 5612       nezi.marvin@enron.com       nezi marvin
# 5873      lynne.ruffer@enron.com      lynne ruffer
# 6103     patrick.lewis@enron.com     patrick lewis
# 6144      wayne.vinson@enron.com      wayne vinson
#
#                                                  x_from   x_from_cleaned  \
# 168   thomas, john buckner </o=enron/ou=na/cn=recipi...      john thomas
# 220   black, tamara jae </o=enron/ou=na/cn=recipient...     tamara black
# 338   leite, francisco pinto </o=enron/ou=na/cn=reci...  francisco leite
# 1061  davis, mark dana </o=enron/ou=na/cn=recipients...       mark davis
# 1096  miller, mary kay </o=enron/ou=na/cn=recipients...      mary miller
# 1113  foret, leigh ann </o=enron/ou=na/cn=recipients...      leigh foret
# 1553  matson, jo ann </o=enron/ou=na/cn=recipients/c...        jo matson
# 1570  hill, jo ann </o=enron/ou=na/cn=recipients/cn=...          jo hill
# 1628  allex, anne marie </o=enron/ou=na/cn=recipient...       anne allex
# 2296  browning, mary nell </o=enron/ou=na/cn=recipie...    mary browning
# 2577  chance, lee ann </o=enron/ou=na/cn=recipients/...       lee chance
# 3388  murphy, melissa ann </o=enron/ou=na/cn=recipie...   melissa murphy
# 3575  schaffart, gaye lynn </o=enron/ou=na/cn=recipi...   gaye schaffart
# 3824  gray, mary griff </o=enron/ou=na/cn=recipients...        mary gray
# 3826  arnold, thu pham </o=enron/ou=na/cn=recipients...       thu arnold
# 3827  smith, jennifer marie </o=enron/ou=na/cn=recip...   jennifer smith
# 4391  anderson, joel melvin </o=enron/ou=na/cn=recip...    joel anderson
# 4409  moore, mary kay </o=enron/ou=na/cn=recipients/...       mary moore
# 4659  moore, jerry thomas </o=enron/ou=na/cn=recipie...      jerry moore
# 4678  zambrano, jose enrique </o=enron/ou=na/cn=reci...    jose zambrano
# 4736  allen, cathy jo </o=enron/ou=na/cn=recipients/...      cathy allen
# 4820  lewis, jon paul </o=enron/ou=na/cn=recipients/...        jon lewis
# 4914  taylor, helen marie </o=enron/ou=na/cn=recipie...     helen taylor
# 5035  hunter, larry joe </o=enron/ou=na/cn=recipient...     larry hunter
# 5039  arellano, fabian dan </o=enron/ou=na/cn=recipi...  fabian arellano
# 5144  hernandez, ana maria </o=enron/ou=na/cn=recipi...    ana hernandez
# 5152  franklin, mary theresa </o=enron/ou=na/cn=reci...    mary franklin
# 5256  johnson, mary jo </o=enron/ou=na/cn=recipients...     mary johnson
# 5612  marvin, michele nezi </o=enron/ou=na/cn=recipi...   michele marvin
# 5873  ruffer, mary lynne </o=enron/ou=na/cn=recipien...      mary ruffer
# 6103  lewis, william patrick </o=enron/ou=na/cn=reci...    william lewis
# 6144  vinson, donald wayne </o=enron/ou=na/cn=recipi...    donald vinson
#
#            clean_name
# 168       john thomas
# 220      tamara black
# 338   francisco leite
# 1061       mark davis
# 1096      mary miller
# 1113      leigh foret
# 1553        jo matson
# 1570          jo hill
# 1628       anne allex
# 2296    mary browning
# 2577       lee chance
# 3388   melissa murphy
# 3575   gaye schaffart
# 3824        mary gray
# 3826       thu arnold
# 3827   jennifer smith
# 4391    joel anderson
# 4409       mary moore
# 4659      jerry moore
# 4678    jose zambrano
# 4736      cathy allen
# 4820        jon lewis
# 4914     helen taylor
# 5035     larry hunter
# 5039  fabian arellano
# 5144    ana hernandez
# 5152    mary franklin
# 5256     mary johnson
# 5612   michele marvin
# 5873      mary ruffer
# 6103    william lewis
# 6144    donald vinson

# %%
# manual review, update where names are not equal
# 
# decision based on most gender-strong form of the name assumption
# 
# 

cd.loc[cd['m_from_cleaned'] == 'kay miller', 'clean_name'] = 'kay miller'
cd.loc[cd['m_from_cleaned'] == 'ann foret', 'clean_name'] = 'ann foret'
cd.loc[cd['m_from_cleaned'] == 'ann hill', 'clean_name'] = 'ann hill'
cd.loc[cd['m_from_cleaned'] == 'ann matson', 'clean_name'] = 'ann matson'
cd.loc[cd['m_from_cleaned'] == 'ann chance', 'clean_name'] = 'ann chance'
cd.loc[cd['m_from_cleaned'] == 'lynn schaffart', 'clean_name'] = 'lynn schaffart'

# clean ' from strings
cd.loc[cd['m_from_cleaned'] == 'chenee\' franklin', 'clean_name'] = 'chenee franklin'
cd.loc[cd['m_from_cleaned'] == '\'todd\' delahoussaye', 'clean_name'] = 'todd delahoussaye'

# %% [markdown]
# ### Separate, Clean First Name for Scraping

# %%
cd['gender_query'] = cd['clean_name'].str.extract('^([A-Za-z\'-]+) [A-Za-z\'-]+$')
cd.head()
# Out:
#                        m_from    m_from_cleaned              x_from  \
# 0     phillip.allen@enron.com     phillip allen     phillip k allen
# 1        ina.rangel@enron.com        ina rangel          ina rangel
# 3  rebecca.cantrell@enron.com  rebecca cantrell  rebecca w cantrell
# 4      paul.kaufman@enron.com      paul kaufman        paul kaufman
# 6  stephanie.miller@enron.com  stephanie miller    stephanie miller
#
#      x_from_cleaned        clean_name gender_query
# 0     phillip allen     phillip allen      phillip
# 1        ina rangel        ina rangel          ina
# 3  rebecca cantrell  rebecca cantrell      rebecca
# 4      paul kaufman      paul kaufman         paul
# 6  stephanie miller  stephanie miller    stephanie

# %% [markdown]
# ### Remove Hyphen From Strings

# %%
# contains '-'
cond = cd.gender_query.str.contains('-')

# return fields
cd[cond]
# Out:
#                                 m_from          m_from_cleaned  \
# 73          sarah-joy.hunter@enron.com        sarah-joy hunter
# 615        jan-erland.bekeng@enron.com       jan-erland bekeng
# 2021  xochitl-alexis.velasco@enron.com  xochitl-alexis velasco
# 2355      sladana-anna.kulic@enron.com      sladana-anna kulic
# 2727           seung-taek.oh@enron.com           seung-taek oh
# 5343            jung-suk.suh@enron.com            jung-suk suh
# 5961             jae-moo.lee@enron.com             jae-moo lee
#
#                                                  x_from  \
# 73                                     sarah-joy hunter
# 615                                   jan-erland bekeng
# 2021                             xochitl-alexis velasco
# 2355  kulic, sladana-anna </o=enron/ou=na/cn=recipie...
# 2727  oh, seung-taek </o=enron/ou=na/cn=recipients/c...
# 5343                                       jung-suk suh
# 5961                                        jae-moo lee
#
#               x_from_cleaned              clean_name    gender_query
# 73          sarah-joy hunter        sarah-joy hunter       sarah-joy
# 615        jan-erland bekeng       jan-erland bekeng      jan-erland
# 2021  xochitl-alexis velasco  xochitl-alexis velasco  xochitl-alexis
# 2355      sladana-anna kulic      sladana-anna kulic    sladana-anna
# 2727           seung-taek oh           seung-taek oh      seung-taek
# 5343            jung-suk suh            jung-suk suh        jung-suk
# 5961             jae-moo lee             jae-moo lee         jae-moo

# %%
# manual review, hyphen names return bad values from web query
#
# removing one name and learing the most gender-strong form for query
#
#

cd.loc[cd['gender_query'] == 'sarah-joy', 'gender_query'] = 'sarah'
cd.loc[cd['gender_query'] == 'jan-erland', 'gender_query'] = 'jan'
cd.loc[cd['gender_query'] == 'sladana-anna', 'gender_query'] = 'anna'
cd.loc[cd['gender_query'] == 'seung-taek', 'gender_query'] = 'seung'
cd.loc[cd['gender_query'] == 'xochitl-alexis', 'gender_query'] = 'alexis'
cd.loc[cd['gender_query'] == 'jung-suk', 'gender_query'] = 'jung'
cd.loc[cd['gender_query'] == 'jae-moo', 'gender_query'] = 'jae'

# %%
cd[cd.gender_query == 'estalee']
# Out:
#                        m_from m_from_cleaned  \
# 2163  estalee.russi@enron.com  estalee russi
#
#                                                  x_from x_from_cleaned  \
# 2163  russi, estalee </o=enron/ou=na/cn=recipients/c...  estalee russi
#
#          clean_name gender_query
# 2163  estalee russi      estalee

# %%
len(cd.drop_duplicates('gender_query'))
# Out:
# 1699

# %%
len(cd)
# Out:
# 5930

# %% [markdown]
# ### Web Scraping the Gender

# %%
# create name series
fname_series = []
fname_series = cd.drop_duplicates('gender_query').gender_query

# sort values, reset index
fname_series = fname_series.sort_values()
fname_series = fname_series.reset_index(drop=True)

# %%
# create list for web scrape
print(len(fname_series))
fname_list = fname_series.values.tolist()
# Out:
# 1699

# %%
#
# baby name guesser function
#

def get_gender_guesser(name):
    
    # capture page response
    with HTMLSession() as s:
        
        url = b_url + name
        
        # set request var
        r = s.get(url, headers=headers)

        # parse out gender
        if r.html.search('It\'s a {}!') is not None:
            gender = r.html.search('It\'s a {}!')[0]
        else:
            gender = 'not_found'

        # record captures
        csv_writer.writerow([name, url, gender])

# %%
# %%time
#
# Pass names to gpeters.com baby name guesser
#

# base url
b_url = 'https://www.gpeters.com/names/baby-names.php?name='

# emulate browser
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'
}

# import library
from requests_html import HTML, HTMLSession
import csv
import concurrent.futures

# create output csv
csv_file = open('./data/name_scrape_guesser.csv', 'w', newline='')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(['name', 'url', 'gender'])

# concurrent futures executor
with concurrent.futures.ThreadPoolExecutor() as executor:  
    future = executor.map(get_gender_guesser, fname_list)
    
# close csv
csv_file.close()
# Out:
# Wall time: 1min 51s

# %%
# import csv scrape
g_df = pd.read_csv('./data/name_scrape_guesser.csv')

# drop duplicates
g_df = g_df.drop_duplicates()

# sort values & reset index
g_df = g_df.sort_values('name').reset_index(drop=True)

# drop the URLs used to scrape
g_df = g_df[['name', 'gender']]
len(g_df)
# Out:
# 1699

# %%
# correcting gender return

g_df.loc[g_df['name'] == 'todd', 'gender'] = 'boy' # todd is a boy
g_df.loc[g_df['name'] == 'gay', 'gender'] = 'girl' # todd is a boy

# %%
# check length
a = len(g_df[g_df.gender == 'not_found'])
b = len(g_df)
print('{} of {} not found.'.format(a, b))

# view head
g_df.head()
# Out:
# 61 of 1699 not found.
#        name gender
# 0     aamir    boy
# 1     aaron    boy
# 2  abhijeet    boy
# 3      adam    boy
# 4    adarsh    boy

# %%
g_df[g_df.gender == 'not_found'][0:50]
# Out:
#              name     gender
# 24      albernita  not_found
# 40         alhamd  not_found
# 113      arquella  not_found
# 154        bessik  not_found
# 190      breanden  not_found
# 201      britaldo  not_found
# 220      cantekin  not_found
# 240       castlen  not_found
# 267      chonawee  not_found
# 359        datren  not_found
# 378        dejoun  not_found
# 448        elberg  not_found
# 480       estalee  not_found
# 521         freyd  not_found
# 529        gallin  not_found
# 545          geiv  not_found
# 564      geynille  not_found
# 619        hemmat  not_found
# 707        jebong  not_found
# 724      jevaughn  not_found
# 757       jonalan  not_found
# 776    juantongia  not_found
# 851     khymberly  not_found
# 883      kunapuli  not_found
# 910        lazure  not_found
# 922        legale  not_found
# 932         lerea  not_found
# 970        luchas  not_found
# 1001     marchris  not_found
# 1097    mingcheng  not_found
# 1108       miyung  not_found
# 1129  musslewhite  not_found
# 1151        nedre  not_found
# 1152       neeran  not_found
# 1176       ningya  not_found
# 1180        nolda  not_found
# 1191    olabowale  not_found
# 1193       olemma  not_found
# 1243  pinnamaneni  not_found
# 1263      ragayle  not_found
# 1265      rahmaan  not_found
# 1324      rinetia  not_found
# 1349      ronggen  not_found
# 1370      rudwell  not_found
# 1382       sabrae  not_found
# 1444     shemeika  not_found
# 1452      shielah  not_found
# 1459       shouan  not_found
# 1463       sidrac  not_found
# 1509       suryan  not_found

# %% [markdown]
# ### Merge Name & Gender to DataFrame

# %%
# merge 
m_df = pd.merge(cd, g_df, how='left', left_on='gender_query', right_on='name')
print(len(m_df))
m_df.head()
# Out:
# 5930
#                        m_from    m_from_cleaned              x_from  \
# 0     phillip.allen@enron.com     phillip allen     phillip k allen
# 1        ina.rangel@enron.com        ina rangel          ina rangel
# 2  rebecca.cantrell@enron.com  rebecca cantrell  rebecca w cantrell
# 3      paul.kaufman@enron.com      paul kaufman        paul kaufman
# 4  stephanie.miller@enron.com  stephanie miller    stephanie miller
#
#      x_from_cleaned        clean_name gender_query       name gender
# 0     phillip allen     phillip allen      phillip    phillip    boy
# 1        ina rangel        ina rangel          ina        ina   girl
# 2  rebecca cantrell  rebecca cantrell      rebecca    rebecca   girl
# 3      paul kaufman      paul kaufman         paul       paul    boy
# 4  stephanie miller  stephanie miller    stephanie  stephanie   girl

# %%
# updating values that returned 'not_found' but were verified individually

manual_updates = dict(
    [
('shemeika landry', 'girl'),
('castlen moore', 'girl'),
('geynille dillingham', 'girl'),
('albernita travis', 'girl'),
('taquesha frank', 'girl'),
('geiv dubash', 'boy'),
('luchas johnson', 'boy'),
('estalee russi', 'girl'),
('gay mayeux', 'girl'),
('musslewhite diane', 'girl'),
('sidrac flores', 'boy'),
('khymberly booth', 'girl'),
('elberg gelin', 'boy'),
('tantra invedy', 'boy'),
    ])

for k, v in manual_updates.items():
    m_df.loc[m_df['clean_name'] == k, 'gender'] = v

# %%
# export csv for gender key
email_gender_key = m_df[['m_from', 'name', 'gender']]
email_gender_key.head()
# Out:
#                        m_from       name gender
# 0     phillip.allen@enron.com    phillip    boy
# 1        ina.rangel@enron.com        ina   girl
# 2  rebecca.cantrell@enron.com    rebecca   girl
# 3      paul.kaufman@enron.com       paul    boy
# 4  stephanie.miller@enron.com  stephanie   girl

# %%
email_gender_key.to_csv('./data/email_gender_key.csv', index=False, index_label=False)

# %%
# merge DataFrame with the genders, join on email address
df_gender = pd.merge(df, email_gender_key, how='left', on='m_from')

# %%
df_gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169285 entries, 0 to 169284
# Data columns (total 21 columns):
# f_dir        169285 non-null object
# m_id         169285 non-null object
# m_date       169285 non-null object
# m_from       169285 non-null object
# m_to         163413 non-null object
# m_cc         52714 non-null object
# m_bcc        50250 non-null object
# m_subj       162429 non-null object
# mime_vers    169285 non-null float64
# cont_type    169285 non-null object
# encode       169285 non-null object
# x_from       169285 non-null object
# x_to         164697 non-null object
# x_cc         50633 non-null object
# x_bcc        131 non-null object
# x_fold       169285 non-null object
# x_orig       169285 non-null object
# x_fname      167315 non-null object
# m_body       169285 non-null object
# name         162847 non-null object
# gender       162847 non-null object
# dtypes: float64(1), object(20)
# memory usage: 28.4+ MB

# %%
#
# export DataFrame for later work
#

# df_gender.to_csv('./data/02_add_gender.csv', index=False, index_label=False)
df_gender.head()
# Out:
#                      f_dir                                           m_id  \
# 0     allen-p/_sent_mail/1  <18782981.1075855378110.JavaMail.evans@thyme>
# 1    allen-p/_sent_mail/10  <15464986.1075855378456.JavaMail.evans@thyme>
# 2   allen-p/_sent_mail/100  <24216240.1075855687451.JavaMail.evans@thyme>
# 3  allen-p/_sent_mail/1000  <13505866.1075863688222.JavaMail.evans@thyme>
# 4  allen-p/_sent_mail/1001  <30922949.1075863688243.JavaMail.evans@thyme>
#
#                                   m_date                   m_from  \
# 0  Mon, 14 May 2001 16:39:00 -0700 (PDT)  phillip.allen@enron.com
# 1   Fri, 4 May 2001 13:51:00 -0700 (PDT)  phillip.allen@enron.com
# 2  Wed, 18 Oct 2000 03:00:00 -0700 (PDT)  phillip.allen@enron.com
# 3  Mon, 23 Oct 2000 06:13:00 -0700 (PDT)  phillip.allen@enron.com
# 4  Thu, 31 Aug 2000 05:07:00 -0700 (PDT)  phillip.allen@enron.com
#
#                       m_to m_cc m_bcc     m_subj  mime_vers  \
# 0     tim.belden@enron.com  NaN   NaN        NaN        1.0
# 1  john.lavorato@enron.com  NaN   NaN        Re:        1.0
# 2   leah.arsdall@enron.com  NaN   NaN   Re: test        1.0
# 3    randall.gay@enron.com  NaN   NaN        NaN        1.0
# 4     greg.piper@enron.com  NaN   NaN  Re: Hello        1.0
#
#                       cont_type  ...           x_from  \
# 0  text/plain; charset=us-ascii  ...  Phillip K Allen
# 1  text/plain; charset=us-ascii  ...  Phillip K Allen
# 2  text/plain; charset=us-ascii  ...  Phillip K Allen
# 3  text/plain; charset=us-ascii  ...  Phillip K Allen
# 4  text/plain; charset=us-ascii  ...  Phillip K Allen
#
#                                                 x_to x_cc x_bcc  \
# 0           Tim Belden <Tim Belden/Enron@EnronXGate>  NaN   NaN
# 1  John J Lavorato <John J Lavorato/ENRON@enronXg...  NaN   NaN
# 2                                   Leah Van Arsdall  NaN   NaN
# 3                                      Randall L Gay  NaN   NaN
# 4                                         Greg Piper  NaN   NaN
#
#                                               x_fold   x_orig  \
# 0  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...  Allen-P
# 1  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...  Allen-P
# 2    \Phillip_Allen_Dec2000\Notes Folders\'sent mail  Allen-P
# 3    \Phillip_Allen_Dec2000\Notes Folders\'sent mail  Allen-P
# 4    \Phillip_Allen_Dec2000\Notes Folders\'sent mail  Allen-P
#
#                        x_fname  \
# 0  pallen (Non-Privileged).pst
# 1  pallen (Non-Privileged).pst
# 2                   pallen.nsf
# 3                   pallen.nsf
# 4                   pallen.nsf
#
#                                               m_body     name gender
# 0                               Here is our forecast  phillip    boy
# 1  Traveling to have a business meeting takes the...  phillip    boy
# 2                     test successful.  way to go!!!  phillip    boy
# 3  Randy,   Can you send me a schedule of the sal...  phillip    boy
# 4                  Let's shoot for Tuesday at 11:45.  phillip    boy
#
# [5 rows x 21 columns]

# %%
# generate sample for review of gender accuracy
gender_sample = df_gender[['m_from', 'name', 'gender']].sample(n=100, random_state=1)

# %%
gender_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 155758 to 130304
# Data columns (total 3 columns):
# m_from    100 non-null object
# name      98 non-null object
# gender    98 non-null object
# dtypes: object(3)
# memory usage: 3.1+ KB

# %%
gender_sample[0:50]
# Out:
#                                m_from       name gender
# 155758        mark.dilworth@enron.com       mark    boy
# 143392          sherri.sera@enron.com     sherri   girl
# 135336      sara.shackleton@enron.com       sara   girl
# 21952           karen.denne@enron.com      karen   girl
# 145939          carol.clair@enron.com      carol   girl
# 52041            pete.davis@enron.com       pete    boy
# 30829      carolyn.centilli@enron.com    carolyn   girl
# 124549      elizabeth.sager@enron.com  elizabeth   girl
# 137366      sara.shackleton@enron.com       sara   girl
# 65073            tana.jones@enron.com       tana   girl
# 73575      shawn.cumberland@enron.com      shawn    boy
# 52187            pete.davis@enron.com       pete    boy
# 140309     jeffrey.shankman@enron.com    jeffrey    boy
# 167199          kysa.alport@enron.com       kysa    boy
# 85597       tori.kuykendall@enron.com       tori   girl
# 80566             f..keavey@enron.com      peter    boy
# 4643              eric.bass@enron.com       eric    boy
# 37178        regina.perkins@enron.com     regina   girl
# 80424            chris.long@enron.com      chris    boy
# 90945       matthew.lenhart@enron.com    matthew    boy
# 103359            a..martin@enron.com     thomas    boy
# 87467              lavorato@enron.com       john    boy
# 100952          scott.healy@enron.com      scott    boy
# 102804             kay.mann@enron.com        kay   girl
# 102199             kay.mann@enron.com        kay   girl
# 158559          phil.polsky@enron.com       phil    boy
# 58753             dan.lyons@enron.com        dan    boy
# 5358              eric.bass@enron.com       eric    boy
# 104229       mike.mcconnell@enron.com       mike    boy
# 28232         jeff.dasovich@enron.com       jeff    boy
# 63945           david.minns@enron.com      david    boy
# 54637         jubran.whalan@enron.com     jubran    boy
# 152490       kerri.thompson@enron.com      kerri   girl
# 123112           don.miller@enron.com        don    boy
# 117149    debra.perlingiere@enron.com      debra   girl
# 73061    ravi.thuraisingham@enron.com       ravi    boy
# 109219           scott.neal@enron.com      scott    boy
# 24441   enron.announcements@enron.com        NaN    NaN
# 90673       matthew.lenhart@enron.com    matthew    boy
# 115627    debra.perlingiere@enron.com      debra   girl
# 43655        tracy.geaccone@enron.com      tracy   girl
# 79035        shelley.corman@enron.com    shelley   girl
# 167338            ted.bland@enron.com        ted    boy
# 90974       matthew.lenhart@enron.com    matthew    boy
# 99615              kay.mann@enron.com        kay   girl
# 18511         michelle.cash@enron.com   michelle   girl
# 6317         patti.thompson@enron.com      patti   girl
# 138829        louis.dicarlo@enron.com      louis    boy
# 63831        mark.greenberg@enron.com       mark    boy
# 113063    john.kiani-aslani@enron.com       john    boy

# %%
gender_sample[50:]
# Out:
#                              m_from       name gender
# 118051         l..nicolay@enron.com    christi   girl
# 152668     cara.semperger@enron.com       cara   girl
# 39632     kevin.cousineau@enron.com      kevin    boy
# 110955         mark.whitt@enron.com       mark    boy
# 57016         marie.heard@enron.com      marie   girl
# 151026         kate.symes@enron.com       kate   girl
# 63952         marie.heard@enron.com      marie   girl
# 66974         justin.boyd@enron.com     justin   girl
# 107198         pete.davis@enron.com       pete    boy
# 166209      julie.kearney@enron.com      julie   girl
# 71560      vince.kaminski@enron.com      vince    boy
# 105572         brad.mckay@enron.com       brad    boy
# 46574      ruth.concannon@enron.com       ruth   girl
# 118854          m..presto@enron.com      kevin    boy
# 89156     matthew.lenhart@enron.com    matthew    boy
# 160146          tk.lohman@enron.com         tk    boy
# 134036    sara.shackleton@enron.com       sara   girl
# 33745       james.derrick@enron.com      james    boy
# 161970          m..taylor@enron.com        liz   girl
# 70940      vince.kaminski@enron.com      vince    boy
# 145422         pete.davis@enron.com       pete    boy
# 69889       sheetal.patel@enron.com    sheetal   girl
# 68560          tana.jones@enron.com       tana   girl
# 60642         kevin.hyatt@enron.com      kevin    boy
# 8236          carol.howes@enron.com      carol   girl
# 16979       michelle.cash@enron.com   michelle   girl
# 28924       jeff.dasovich@enron.com       jeff    boy
# 106093   errol.mclaughlin@enron.com      errol    boy
# 105752         chad.bruce@enron.com       chad    boy
# 34015       james.derrick@enron.com      james    boy
# 138996    stephanie.panus@enron.com  stephanie   girl
# 102395  kathleen.carnahan@enron.com   kathleen   girl
# 100498           kay.mann@enron.com        kay   girl
# 32770         kay.chapman@enron.com        kay   girl
# 37450        jackie.young@enron.com     jackie   girl
# 25640     cristina.zavala@enron.com   cristina   girl
# 52562       peter.keohane@enron.com      peter    boy
# 88986     matthew.lenhart@enron.com    matthew    boy
# 145288         pete.davis@enron.com       pete    boy
# 9419        brian.redmond@enron.com      brian    boy
# 151327         kate.symes@enron.com       kate   girl
# 86358     stephanie.sever@enron.com  stephanie   girl
# 66442       samantha.boyd@enron.com   samantha   girl
# 75685          anne.labbe@enron.com       anne   girl
# 98552            kay.mann@enron.com        kay   girl
# 58487            t..hodge@enron.com    jeffrey    boy
# 160224    pallavi.goradia@enron.com    pallavi   girl
# 109014            eserver@enron.com        NaN    NaN
# 123868    elizabeth.sager@enron.com  elizabeth   girl
# 130304       darren.vanek@enron.com     darren    boy

# %% [markdown]
# ### Ending Stats

# %%
# execution time
print("--- %s seconds ---" % (time.time() - start_time))

# total email body chars (for process tracking)
current_chars = df.m_body.apply(len).sum()

print('{} of {} characters removed from corpus for {} reduction.'.format(current_chars, start_chars,((start_chars-current_chars)/(start_chars+current_chars))))
# Out:
# --- 122.03231763839722 seconds ---
# 135952755 of 135952755 characters removed from corpus for 0.0 reduction.
