# %% [markdown]
# # 02 Add Gender

# %%
# import library
import pandas as pd
import re

# %%
# import working df
df = pd.read_csv('./data/01_first_clean.csv', header=0, index_col=False)

# %%
# check info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138752 entries, 0 to 138751
# Data columns (total 20 columns):
# f_dir          138752 non-null object
# m_id           138752 non-null object
# m_date         138752 non-null object
# m_from         138752 non-null object
# m_to           132960 non-null object
# m_cc           42401 non-null object
# m_bcc          41009 non-null object
# m_subj         132115 non-null object
# mime_vers      138752 non-null float64
# cont_type      138752 non-null object
# encode         138752 non-null object
# x_from         138752 non-null object
# x_to           134187 non-null object
# x_cc           41339 non-null object
# x_bcc          117 non-null object
# x_fold         138752 non-null object
# x_orig         138752 non-null object
# x_fname        136945 non-null object
# m_body         138752 non-null object
# sent_counts    138752 non-null int64
# dtypes: float64(1), int64(1), object(18)
# memory usage: 21.2+ MB

# %% [markdown]
# ### Separate Columns of Interest (Emails, Internal From Field)

# %%
# take out columns for work
fn = df[['m_from', 'x_from']].copy()

# drop duplicates based on email address
fn = fn.drop_duplicates(subset='m_from')

# reset index for the new df
fn = fn.reset_index(drop=True)

# make both columns lowercase
fn.m_from = fn.m_from.str.lower()
fn.x_from = fn.x_from.str.lower()

# %%
# show example of m_from
fn.head()
# Out:
#                        m_from                     x_from
# 0     phillip.allen@enron.com            phillip k allen
# 1        ina.rangel@enron.com                 ina rangel
# 2   critical.notice@enron.com  critical.notice@enron.com
# 3  rebecca.cantrell@enron.com         rebecca w cantrell
# 4      paul.kaufman@enron.com               paul kaufman

# %%
def clean_m_from(s):
    """Use this to recover names from the email addresses
       with regular expression captures. 8 cases are outlined
       below for capture. A final case (ZZ) wipes the cell.
       
       Wiped cell will be used to consider value fills from
       strings recovered from the X-From column."""
    #
    # cleans email addresses for the following cases, returning a string to place in a subsequent (name) column.
    # the following notation is used to explain cases:
    #     fname = first name
    #     lname = last name
    #     mname = middle name
    #     init = initial
    #     ffname = another word considered with first name
    #     scotts = name string contains an apostrophe
    #
    # CASE 01: fname'.lname'@enron.com (fname lname)
    # CASE 02: string@enron.com (string)
    # CASE 03: finit..lname@enron.com or finit.lname@enron.com (finit lname)
    # CASE 04: fname.minit.lname@enron.com (fname lname)
    # CASE 05: fname-ffname.lname@enron.com (fname-ffname lname)
    # CASE 06: fname.lname.enronxgate@enron.com (fname lname)
    # CASE 07: fname_lname@enron.com (fname lname)
    # CASE 08: fname.lname-llname@enron.com (fname lname-llname)
    # CASE ZZ [CREATE NULL]: @enron.com ('')
    # 

    try:

        # CASE 01
        p = '^([A-Za-z\']+)[.]([A-Za-z\']+)@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)
                
        # CASE 02
        p = '^([A-Za-z]+)@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]) # (string)
                    
        # CASE 03
        p = '^([A-Za-z])[.]{1,2}([A-Za-z]+)@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (finit lname)

        # CASE 04
        p = '^([A-Za-z]+)[.][A-Za-z][.]([A-Za-z]+)@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)
            
        # CASE 05
        p = '^([A-Za-z]+[-][A-Za-z]+)[.]([A-Za-z]+)@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname-ffname lname)
            
        # CASE 06
        p = '^([A-Za-z]+)[.]([A-Za-z]+).enronxgate@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)
        
        # CASE 07
        p = '^([A-Za-z\']+)[_]([A-Za-z\']+)@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)
        
        # CASE 08
        p = '^([A-Za-z]+)[.]([A-Za-z]+[-][A-Za-z]+)@enron.com$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)

        # CASE R02
        p = '^[A-Za-z] [A-Za-z\'-]+$'
        if re.search(p, s):
            s = ''

        # CASE R01
        buzz_words = ['team', 'technology', 'security', 'enron', 'chairman', 'office', 'announcement', 'wizard', 'notice', 'address', 'hr taylor', 'coo jeff', 'infrastructure', 'ubsw', 'europe',
                      'human', 'resources', 'connection', 'ibuyit', 'users', 'livelink', 'registrar', 'global', 'business', 'compensation', 'executive', 'risk', 'analytics', 'daemon', 'information',
                      'management', 'helpdesk', 'project', 'sunrise', 'oncall', 'credit', 'union', 'notification', 'central', 'communication', 'center', 'parking', 'transportation', 'international',
                      'diversity', 'survey', 'automation', 'document', 'exec', 'iscinfra', 'public', 'relations', 'controls', 'exchange', 'cms router', 'hotline', 'admin', 'pr id', 'expertfinder',
                      'notes', 'the buzz', 'gpg dss', 'xi xi', 'enw piper', 'institute', 'agent', 'tarrif']
                      
        for word in buzz_words:
            if re.search(word, s):
                s = ''
        
        # CASE ZZ
        p = '^[A-Za-z\'-]+ [A-Za-z\'-]+$'
        if re.search(p, s):
            s
        else:
            s = ''

        return(s)
    
    except:
        
        print('EXCEPTION RETURN: ' + s)
        return(s)

# %% [markdown]
# ### Parse Names from Email Addresses

# %%
# run custom function to create a new column
fn['m_from_cleaned'] = fn.m_from.apply(clean_m_from)

# change column order
fn = fn[['m_from', 'm_from_cleaned', 'x_from']]

# check head
fn.head()
# Out:
#                        m_from    m_from_cleaned                     x_from
# 0     phillip.allen@enron.com     phillip allen            phillip k allen
# 1        ina.rangel@enron.com        ina rangel                 ina rangel
# 2   critical.notice@enron.com                    critical.notice@enron.com
# 3  rebecca.cantrell@enron.com  rebecca cantrell         rebecca w cantrell
# 4      paul.kaufman@enron.com      paul kaufman               paul kaufman

# %%
def clean_x_from(s):
    """Use this to recover names from the X-From column
       with regular expression captures. [ ] cases are outlined
       below for capture. A final case (ZZ) wipes the cell.
       
       Wiped cell will be used to match any possible fills between
       m_from and x_from."""
    #
    # cleans email addresses for the following cases, returning a string to place in a subsequent (name) column.
    # the following notation is used to explain cases:
    #     fname = first name
    #     lname = last name
    #     mname = middle name
    #     init = initial
    #     ffname = another word considered with first name
    #     scotts = name string contains an apostrophe
    #
    # CASE 01: 
    # CASE 02: 
    # CASE 03: 
    # CASE 04: 
    # CASE 05: 
    # CASE 06: 
    # CASE 07: 
    # CASE 08: 
    # CASE ZZ [CREATE NULL]: @enron.com ('')
    # 

    try:
        
        # CASE 01
        p = '^([A-Za-z]+) ([A-Za-z]+)$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)

        # CASE 03
        p = '^([A-Za-z]+), ([A-Za-z]+) [A-Za-z][.] {1,2}<.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[2]+' '+s[1]) # (fname lname)    
            
        # CASE 02
        p = '^([A-Za-z\'-]+), ([A-Za-z\'-]+) <.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[2]+' '+s[1]) # (fname lname)
            
            # removes 'team.' subsets of this pattern
            if re.search('team', s):
                s = ''

        # CASE 14
        p = '^[A-Za-z] ([A-Za-z]+) ([A-Za-z]+) <.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)                
                
        # CASE 04
        p = '^([A-Za-z]+) [A-Za-z] ([A-Za-z]+) <.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)

        # CASE 05
        p = '^([A-Za-z]+) ([A-Za-z]+) <.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)
            
        # CASE 06
        p = '^([A-Za-z]+) [A-Za-z]{2,} ([A-Za-z]+) <.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)

        # CASE 13
        p = '^[A-Za-z] ([A-Za-z]+) ([A-Za-z]+)$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)
            
        # CASE 07
        p = '^([A-Za-z]+) [A-Za-z]+ ([A-Za-z]+)$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[1]+' '+s[2]) # (fname lname)
        
        # CASE 08
        p = '^([A-Za-z]+), ([A-Za-z]+) [A-Za-z]+ {1,2}<.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[2]+' '+s[1]) # (fname lname)
            
        # CASE 09
        p = '^([A-Za-z]+), ([A-Za-z]+)$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[2]+' '+s[1]) # (fname lname)
            
        # CASE 10
        p = '^([A-Za-z]+) [A-Za-z]+., ([A-Za-z]+) <.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[2]+' '+s[1]) # (fname lname)
            
        # CASE 11
        p = '^([A-Za-z]+) [A-Za-z]+[.], ([A-Za-z]+) [A-Za-z][.] <.+$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[2]+' '+s[1]) # (fname lname)

        # CASE 12
        p = '^([A-Za-z]+) [A-Za-z]+[.], ([A-Za-z]+)[A-Za-z .]{0,3}$'
        if re.search(p, s):
            s = re.search(p, s)
            s = (s[2]+' '+s[1]) # (fname lname)

        # CASE R02
        p = '^[A-Za-z] [A-Za-z\'-]+$'
        if re.search(p, s):
            s = ''

        # CASE R01
        buzz_words = ['team', 'technology', 'security', 'enron', 'chairman', 'office', 'announcement', 'wizard', 'notice', 'address', 'hr taylor', 'coo jeff', 'infrastructure', 'ubsw', 'europe',
                      'human', 'resources', 'connection', 'ibuyit', 'users', 'livelink', 'registrar', 'global', 'business', 'compensation', 'executive', 'risk', 'analytics', 'daemon', 'information',
                      'management', 'helpdesk', 'project', 'sunrise', 'oncall', 'credit', 'union', 'notification', 'central', 'communication', 'center', 'parking', 'transportation', 'international',
                      'diversity', 'survey', 'automation', 'document', 'exec', 'iscinfra', 'public', 'relations', 'controls', 'exchange', 'cms router', 'hotline', 'admin', 'pr id', 'expertfinder',
                      'notes', 'the buzz', 'gpg dss', 'xi xi', 'enw piper', 'institute', 'agent', 'tarrif']
                      
        for word in buzz_words:
            if re.search(word, s):
                s = ''
        
        # CASE ZZ
        p = '^[A-Za-z\'-]+ [A-Za-z\'-]+$'
        if re.search(p, s):
            s
        else:
            s = ''
        
        return(s)
    
    except:
        
        print('EXCEPTION RETURN: ' + s.group())
        return(s)

# %% [markdown]
# ### Parse Names from X-From Field

# %%
# x_from
fn['x_from_cleaned'] = fn.x_from.apply(clean_x_from)

# peek results
fn.head()
# Out:
#                        m_from    m_from_cleaned                     x_from  \
# 0     phillip.allen@enron.com     phillip allen            phillip k allen
# 1        ina.rangel@enron.com        ina rangel                 ina rangel
# 2   critical.notice@enron.com                    critical.notice@enron.com
# 3  rebecca.cantrell@enron.com  rebecca cantrell         rebecca w cantrell
# 4      paul.kaufman@enron.com      paul kaufman               paul kaufman
#
#      x_from_cleaned
# 0     phillip allen
# 1        ina rangel
# 2
# 3  rebecca cantrell
# 4      paul kaufman

# %% [markdown]
# ### Remove Non-Names

# %%
# condition to catch rows where both clean columns are blank
cond = (fn.m_from_cleaned == '') & (fn.x_from_cleaned == '')

# copy new df of non-condition return
cd = fn[~cond].copy()

# %% [markdown]
# # fill m_from_cleaned empty values with the value from x_from_cleaned
# cd.loc[cd['m_from_cleaned'] == '', 'm_from_cleaned'] = cd['x_from_cleaned']
#
# # fill x_from_cleaned empty values with the value from m_from_cleaned
# cd.loc[cd['x_from_cleaned'] == '', 'x_from_cleaned'] = cd['m_from_cleaned']

# %%
# create a capture column for the final fname lname
cd['clean_name'] = cd['x_from_cleaned']

# fill blanks with other column returns
cd.loc[cd['clean_name'] == '', 'clean_name'] = cd['m_from_cleaned']

# %% [markdown]
# ### Evaluate Conflicts Between Parses

# %%
# return differences between the two parsed values if they both returned a value
makin_picks = cd[(cd.m_from_cleaned != cd.x_from_cleaned) & (cd.m_from_cleaned != '') & (cd.x_from_cleaned != '')]

# manually review mismatches
print(len(makin_picks))
makin_picks
# Out:
# 30
#                           m_from    m_from_cleaned  \
# 199          jae.black@enron.com         jae black
# 307        pinto.leite@enron.com       pinto leite
# 969         dana.davis@enron.com        dana davis
# 1000        kay.miller@enron.com        kay miller
# 1018         ann.foret@enron.com         ann foret
# 1447          ann.hill@enron.com          ann hill
# 1458        ann.matson@enron.com        ann matson
# 1505       marie.allex@enron.com       marie allex
# 2132     nell.browning@enron.com     nell browning
# 2398        ann.chance@enron.com        ann chance
# 3178        ann.murphy@enron.com        ann murphy
# 3351    lynn.schaffart@enron.com    lynn schaffart
# 3582        griff.gray@enron.com        griff gray
# 3584       marie.smith@enron.com       marie smith
# 4117   melvin.anderson@enron.com   melvin anderson
# 4133         kay.moore@enron.com         kay moore
# 4369      thomas.moore@enron.com      thomas moore
# 4388  enrique.zambrano@enron.com  enrique zambrano
# 4531        paul.lewis@enron.com        paul lewis
# 4622      marie.taylor@enron.com      marie taylor
# 4747      dan.arellano@enron.com      dan arellano
# 4846   maria.hernandez@enron.com   maria hernandez
# 4855  theresa.franklin@enron.com  theresa franklin
# 4970        jo.johnson@enron.com        jo johnson
# 5305        joe.hunter@enron.com        joe hunter
# 5312       nezi.marvin@enron.com       nezi marvin
# 5565      lynne.ruffer@enron.com      lynne ruffer
# 5793     patrick.lewis@enron.com     patrick lewis
# 5836      wayne.vinson@enron.com      wayne vinson
# 5869       pham.arnold@enron.com       pham arnold
#
#                                                  x_from   x_from_cleaned  \
# 199   black, tamara jae </o=enron/ou=na/cn=recipient...     tamara black
# 307   leite, francisco pinto </o=enron/ou=na/cn=reci...  francisco leite
# 969   davis, mark dana </o=enron/ou=na/cn=recipients...       mark davis
# 1000  miller, mary kay </o=enron/ou=na/cn=recipients...      mary miller
# 1018  foret, leigh ann </o=enron/ou=na/cn=recipients...      leigh foret
# 1447  hill, jo ann </o=enron/ou=na/cn=recipients/cn=...          jo hill
# 1458  matson, jo ann </o=enron/ou=na/cn=recipients/c...        jo matson
# 1505  allex, anne marie </o=enron/ou=na/cn=recipient...       anne allex
# 2132  browning, mary nell </o=enron/ou=na/cn=recipie...    mary browning
# 2398  chance, lee ann </o=enron/ou=na/cn=recipients/...       lee chance
# 3178  murphy, melissa ann </o=enron/ou=na/cn=recipie...   melissa murphy
# 3351  schaffart, gaye lynn </o=enron/ou=na/cn=recipi...   gaye schaffart
# 3582  gray, mary griff </o=enron/ou=na/cn=recipients...        mary gray
# 3584  smith, jennifer marie </o=enron/ou=na/cn=recip...   jennifer smith
# 4117  anderson, joel melvin </o=enron/ou=na/cn=recip...    joel anderson
# 4133  moore, mary kay </o=enron/ou=na/cn=recipients/...       mary moore
# 4369  moore, jerry thomas </o=enron/ou=na/cn=recipie...      jerry moore
# 4388  zambrano, jose enrique </o=enron/ou=na/cn=reci...    jose zambrano
# 4531  lewis, jon paul </o=enron/ou=na/cn=recipients/...        jon lewis
# 4622  taylor, helen marie </o=enron/ou=na/cn=recipie...     helen taylor
# 4747  arellano, fabian dan </o=enron/ou=na/cn=recipi...  fabian arellano
# 4846  hernandez, ana maria </o=enron/ou=na/cn=recipi...    ana hernandez
# 4855  franklin, mary theresa </o=enron/ou=na/cn=reci...    mary franklin
# 4970  johnson, mary jo </o=enron/ou=na/cn=recipients...     mary johnson
# 5305  hunter, larry joe </o=enron/ou=na/cn=recipient...     larry hunter
# 5312  marvin, michele nezi </o=enron/ou=na/cn=recipi...   michele marvin
# 5565  ruffer, mary lynne </o=enron/ou=na/cn=recipien...      mary ruffer
# 5793  lewis, william patrick </o=enron/ou=na/cn=reci...    william lewis
# 5836  vinson, donald wayne </o=enron/ou=na/cn=recipi...    donald vinson
# 5869  arnold, thu pham </o=enron/ou=na/cn=recipients...       thu arnold
#
#            clean_name
# 199      tamara black
# 307   francisco leite
# 969        mark davis
# 1000      mary miller
# 1018      leigh foret
# 1447          jo hill
# 1458        jo matson
# 1505       anne allex
# 2132    mary browning
# 2398       lee chance
# 3178   melissa murphy
# 3351   gaye schaffart
# 3582        mary gray
# 3584   jennifer smith
# 4117    joel anderson
# 4133       mary moore
# 4369      jerry moore
# 4388    jose zambrano
# 4531        jon lewis
# 4622     helen taylor
# 4747  fabian arellano
# 4846    ana hernandez
# 4855    mary franklin
# 4970     mary johnson
# 5305     larry hunter
# 5312   michele marvin
# 5565      mary ruffer
# 5793    william lewis
# 5836    donald vinson
# 5869       thu arnold

# %%
# manual review, update where names are not equal
# 
# decision based on most gender-strong form of the name assumption
# 
# 

cd.loc[cd['m_from_cleaned'] == 'kay miller', 'clean_name'] = 'kay miller'
cd.loc[cd['m_from_cleaned'] == 'ann foret', 'clean_name'] = 'ann foret'
cd.loc[cd['m_from_cleaned'] == 'ann hill', 'clean_name'] = 'ann hill'
cd.loc[cd['m_from_cleaned'] == 'ann matson', 'clean_name'] = 'ann matson'
cd.loc[cd['m_from_cleaned'] == 'ann chance', 'clean_name'] = 'ann chance'
cd.loc[cd['m_from_cleaned'] == 'lynn schaffart', 'clean_name'] = 'lynn schaffart'

# clean ' from strings
cd.loc[cd['m_from_cleaned'] == 'chenee\' franklin', 'clean_name'] = 'chenee franklin'
cd.loc[cd['m_from_cleaned'] == '\'todd\' delahoussaye', 'clean_name'] = 'todd delahoussaye'

# %% [markdown]
# ### Separate, Clean First Name for Scraping

# %%
cd['gender_query'] = cd['clean_name'].str.extract('^([A-Za-z\'-]+) [A-Za-z\'-]+$')
cd.head()
# Out:
#                        m_from    m_from_cleaned              x_from  \
# 0     phillip.allen@enron.com     phillip allen     phillip k allen
# 1        ina.rangel@enron.com        ina rangel          ina rangel
# 3  rebecca.cantrell@enron.com  rebecca cantrell  rebecca w cantrell
# 4      paul.kaufman@enron.com      paul kaufman        paul kaufman
# 6  stephanie.miller@enron.com  stephanie miller    stephanie miller
#
#      x_from_cleaned        clean_name gender_query
# 0     phillip allen     phillip allen      phillip
# 1        ina rangel        ina rangel          ina
# 3  rebecca cantrell  rebecca cantrell      rebecca
# 4      paul kaufman      paul kaufman         paul
# 6  stephanie miller  stephanie miller    stephanie

# %% [markdown]
# ### Remove Hyphen From Strings

# %%
# contains '-'
cond = cd.gender_query.str.contains('-')

# return fields
cd[cond]
# Out:
#                                 m_from          m_from_cleaned  \
# 72          sarah-joy.hunter@enron.com        sarah-joy hunter
# 564        jan-erland.bekeng@enron.com       jan-erland bekeng
# 2193      sladana-anna.kulic@enron.com      sladana-anna kulic
# 2541           seung-taek.oh@enron.com           seung-taek oh
# 4800  xochitl-alexis.velasco@enron.com  xochitl-alexis velasco
# 5050            jung-suk.suh@enron.com            jung-suk suh
# 5644             jae-moo.lee@enron.com             jae-moo lee
#
#                                                  x_from  \
# 72                                     sarah-joy hunter
# 564                                   jan-erland bekeng
# 2193  kulic, sladana-anna </o=enron/ou=na/cn=recipie...
# 2541  oh, seung-taek </o=enron/ou=na/cn=recipients/c...
# 4800                             xochitl-alexis velasco
# 5050                                       jung-suk suh
# 5644                                        jae-moo lee
#
#               x_from_cleaned              clean_name    gender_query
# 72          sarah-joy hunter        sarah-joy hunter       sarah-joy
# 564        jan-erland bekeng       jan-erland bekeng      jan-erland
# 2193      sladana-anna kulic      sladana-anna kulic    sladana-anna
# 2541           seung-taek oh           seung-taek oh      seung-taek
# 4800  xochitl-alexis velasco  xochitl-alexis velasco  xochitl-alexis
# 5050            jung-suk suh            jung-suk suh        jung-suk
# 5644             jae-moo lee             jae-moo lee         jae-moo

# %%
# manual review, hyphen names return bad values from web query
#
# removing one name and learing the most gender-strong form for query
#
#

cd.loc[cd['gender_query'] == 'sarah-joy', 'gender_query'] = 'sarah'
cd.loc[cd['gender_query'] == 'jan-erland', 'gender_query'] = 'jan'
cd.loc[cd['gender_query'] == 'sladana-anna', 'gender_query'] = 'anna'
cd.loc[cd['gender_query'] == 'seung-taek', 'gender_query'] = 'seung'
cd.loc[cd['gender_query'] == 'xochitl-alexis', 'gender_query'] = 'alexis'
cd.loc[cd['gender_query'] == 'jung-suk', 'gender_query'] = 'jung'
cd.loc[cd['gender_query'] == 'jae-moo', 'gender_query'] = 'jae'

# %%
cd[cd.gender_query == 'estalee']
# Out:
#                        m_from m_from_cleaned  \
# 2000  estalee.russi@enron.com  estalee russi
#
#                                                  x_from x_from_cleaned  \
# 2000  russi, estalee </o=enron/ou=na/cn=recipients/c...  estalee russi
#
#          clean_name gender_query
# 2000  estalee russi      estalee

# %%
len(cd.drop_duplicates('gender_query'))
# Out:
# 1639

# %%
len(cd)
# Out:
# 5631

# %% [markdown]
# ### Web Scraping the Gender

# %%
# create name series
fname_series = []
fname_series = cd.drop_duplicates('gender_query').gender_query

# sort values, reset index
fname_series = fname_series.sort_values()
fname_series = fname_series.reset_index(drop=True)

# %%
# create list for web scrape
print(len(fname_series))
fname_list = fname_series.values.tolist()
# Out:
# 1639

# %%
#
# baby name guesser function
#

def get_gender_guesser(name):
    
    # capture page response
    with HTMLSession() as s:
        
        url = b_url + name
        
        # set request var
        r = s.get(url, headers=headers)

        # parse out gender
        if r.html.search('It\'s a {}!') is not None:
            gender = r.html.search('It\'s a {}!')[0]
        else:
            gender = 'not_found'

        # record captures
        csv_writer.writerow([name, url, gender])

# %%
# %%time
#
# Pass names to gpeters.com baby name guesser
#

# base url
b_url = 'https://www.gpeters.com/names/baby-names.php?name='

# emulate browser
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'
}

# import library
from requests_html import HTML, HTMLSession
import csv
import concurrent.futures

# create output csv
csv_file = open('./data/name_scrape_guesser.csv', 'w', newline='')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(['name', 'url', 'gender'])

# concurrent futures executor
with concurrent.futures.ThreadPoolExecutor() as executor:  
    future = executor.map(get_gender_guesser, fname_list)
    
# close csv
csv_file.close()
# Out:
# Wall time: 2min 6s

# %%
# import csv scrape
g_df = pd.read_csv('./data/name_scrape_guesser.csv')

# drop duplicates
g_df = g_df.drop_duplicates()

# sort values & reset index
g_df = g_df.sort_values('name').reset_index(drop=True)

# drop the URLs used to scrape
g_df = g_df[['name', 'gender']]
len(g_df)
# Out:
# 1638

# %%
# correcting gender return

g_df.loc[g_df['name'] == 'todd', 'gender'] = 'boy' # todd is a boy
g_df.loc[g_df['name'] == 'gay', 'gender'] = 'girl' # todd is a boy

# %%
# check length
a = len(g_df[g_df.gender == 'not_found'])
b = len(g_df)
print('{} of {} not found.'.format(a, b))

# view head
g_df.head()
# Out:
# 59 of 1638 not found.
#        name gender
# 0     aamir    boy
# 1     aaron    boy
# 2  abhijeet    boy
# 3      adam    boy
# 4    adarsh    boy

# %%
g_df[g_df.gender == 'not_found'][0:50]
# Out:
#              name     gender
# 23      albernita  not_found
# 39         alhamd  not_found
# 111      arquella  not_found
# 150        bessik  not_found
# 184      breanden  not_found
# 211      cantekin  not_found
# 231       castlen  not_found
# 257      chonawee  not_found
# 345        datren  not_found
# 363        dejoun  not_found
# 432        elberg  not_found
# 464       estalee  not_found
# 503         freyd  not_found
# 511        gallin  not_found
# 527          geiv  not_found
# 546      geynille  not_found
# 598        hemmat  not_found
# 681        jebong  not_found
# 697      jevaughn  not_found
# 730       jonalan  not_found
# 748    juantongia  not_found
# 818     khymberly  not_found
# 819        kiddie  not_found
# 851      kunapuli  not_found
# 887        legale  not_found
# 896         lerea  not_found
# 934        luchas  not_found
# 961      marchris  not_found
# 1055    mingcheng  not_found
# 1066       miyung  not_found
# 1085  musslewhite  not_found
# 1106        nedre  not_found
# 1107       neeran  not_found
# 1131       ningya  not_found
# 1134        nolda  not_found
# 1145    olabowale  not_found
# 1147       olemma  not_found
# 1193  pinnamaneni  not_found
# 1211      ragayle  not_found
# 1213      rahmaan  not_found
# 1270      rinetia  not_found
# 1295      ronggen  not_found
# 1316      rudwell  not_found
# 1328       sabrae  not_found
# 1387     shemeika  not_found
# 1395      shielah  not_found
# 1402       shouan  not_found
# 1406       sidrac  not_found
# 1452       suryan  not_found
# 1473       tantra  not_found

# %% [markdown]
# ### Merge Name & Gender to DataFrame

# %%
# merge 
m_df = pd.merge(cd, g_df, how='left', left_on='gender_query', right_on='name')
print(len(m_df))
m_df.head()
# Out:
# 5631
#                        m_from    m_from_cleaned              x_from  \
# 0     phillip.allen@enron.com     phillip allen     phillip k allen
# 1        ina.rangel@enron.com        ina rangel          ina rangel
# 2  rebecca.cantrell@enron.com  rebecca cantrell  rebecca w cantrell
# 3      paul.kaufman@enron.com      paul kaufman        paul kaufman
# 4  stephanie.miller@enron.com  stephanie miller    stephanie miller
#
#      x_from_cleaned        clean_name gender_query       name gender
# 0     phillip allen     phillip allen      phillip    phillip    boy
# 1        ina rangel        ina rangel          ina        ina   girl
# 2  rebecca cantrell  rebecca cantrell      rebecca    rebecca   girl
# 3      paul kaufman      paul kaufman         paul       paul    boy
# 4  stephanie miller  stephanie miller    stephanie  stephanie   girl

# %%
# updating values that returned 'not_found' but were verified individually

manual_updates = dict(
    [
('shemeika landry', 'girl'),
('castlen moore', 'girl'),
('geynille dillingham', 'girl'),
('albernita travis', 'girl'),
('taquesha frank', 'girl'),
('geiv dubash', 'boy'),
('luchas johnson', 'boy'),
('estalee russi', 'girl'),
('gay mayeux', 'girl'),
('musslewhite diane', 'girl'),
('sidrac flores', 'boy'),
('khymberly booth', 'girl'),
('elberg gelin', 'boy'),
('tantra invedy', 'boy'),
    ])

for k, v in manual_updates.items():
    m_df.loc[m_df['clean_name'] == k, 'gender'] = v

# %%
# export csv for gender key
email_gender_key = m_df[['m_from', 'name', 'gender']]
email_gender_key.head()
# Out:
#                        m_from       name gender
# 0     phillip.allen@enron.com    phillip    boy
# 1        ina.rangel@enron.com        ina   girl
# 2  rebecca.cantrell@enron.com    rebecca   girl
# 3      paul.kaufman@enron.com       paul    boy
# 4  stephanie.miller@enron.com  stephanie   girl

# %%
email_gender_key.to_csv('./data/email_gender_key.csv', index=False, index_label=False)

# %%
# merge DataFrame with the genders, join on email address
df_gender = pd.merge(df, email_gender_key, how='left', on='m_from')

# %%
df_gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138752 entries, 0 to 138751
# Data columns (total 22 columns):
# f_dir          138752 non-null object
# m_id           138752 non-null object
# m_date         138752 non-null object
# m_from         138752 non-null object
# m_to           132960 non-null object
# m_cc           42401 non-null object
# m_bcc          41009 non-null object
# m_subj         132115 non-null object
# mime_vers      138752 non-null float64
# cont_type      138752 non-null object
# encode         138752 non-null object
# x_from         138752 non-null object
# x_to           134187 non-null object
# x_cc           41339 non-null object
# x_bcc          117 non-null object
# x_fold         138752 non-null object
# x_orig         138752 non-null object
# x_fname        136945 non-null object
# m_body         138752 non-null object
# sent_counts    138752 non-null int64
# name           132511 non-null object
# gender         132511 non-null object
# dtypes: float64(1), int64(1), object(20)
# memory usage: 24.3+ MB

# %%
#
# export DataFrame for later work
#

df_gender.to_csv('./data/02_add_gender.csv', index=False, index_label=False)
df_gender.head()
# Out:
#                      f_dir                                           m_id  \
# 0     allen-p/_sent_mail/1  <18782981.1075855378110.JavaMail.evans@thyme>
# 1    allen-p/_sent_mail/10  <15464986.1075855378456.JavaMail.evans@thyme>
# 2   allen-p/_sent_mail/100  <24216240.1075855687451.JavaMail.evans@thyme>
# 3  allen-p/_sent_mail/1000  <13505866.1075863688222.JavaMail.evans@thyme>
# 4  allen-p/_sent_mail/1001  <30922949.1075863688243.JavaMail.evans@thyme>
#
#                                   m_date                   m_from  \
# 0  Mon, 14 May 2001 16:39:00 -0700 (PDT)  phillip.allen@enron.com
# 1   Fri, 4 May 2001 13:51:00 -0700 (PDT)  phillip.allen@enron.com
# 2  Wed, 18 Oct 2000 03:00:00 -0700 (PDT)  phillip.allen@enron.com
# 3  Mon, 23 Oct 2000 06:13:00 -0700 (PDT)  phillip.allen@enron.com
# 4  Thu, 31 Aug 2000 05:07:00 -0700 (PDT)  phillip.allen@enron.com
#
#                       m_to m_cc m_bcc     m_subj  mime_vers  \
# 0     tim.belden@enron.com  NaN   NaN        NaN        1.0
# 1  john.lavorato@enron.com  NaN   NaN        Re:        1.0
# 2   leah.arsdall@enron.com  NaN   NaN   Re: test        1.0
# 3    randall.gay@enron.com  NaN   NaN        NaN        1.0
# 4     greg.piper@enron.com  NaN   NaN  Re: Hello        1.0
#
#                       cont_type encode           x_from  \
# 0  text/plain; charset=us-ascii   7bit  Phillip K Allen
# 1  text/plain; charset=us-ascii   7bit  Phillip K Allen
# 2  text/plain; charset=us-ascii   7bit  Phillip K Allen
# 3  text/plain; charset=us-ascii   7bit  Phillip K Allen
# 4  text/plain; charset=us-ascii   7bit  Phillip K Allen
#
#                                                 x_to x_cc x_bcc  \
# 0           Tim Belden <Tim Belden/Enron@EnronXGate>  NaN   NaN
# 1  John J Lavorato <John J Lavorato/ENRON@enronXg...  NaN   NaN
# 2                                   Leah Van Arsdall  NaN   NaN
# 3                                      Randall L Gay  NaN   NaN
# 4                                         Greg Piper  NaN   NaN
#
#                                               x_fold   x_orig  \
# 0  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...  Allen-P
# 1  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...  Allen-P
# 2    \Phillip_Allen_Dec2000\Notes Folders\'sent mail  Allen-P
# 3    \Phillip_Allen_Dec2000\Notes Folders\'sent mail  Allen-P
# 4    \Phillip_Allen_Dec2000\Notes Folders\'sent mail  Allen-P
#
#                        x_fname  \
# 0  pallen (Non-Privileged).pst
# 1  pallen (Non-Privileged).pst
# 2                   pallen.nsf
# 3                   pallen.nsf
# 4                   pallen.nsf
#
#                                               m_body  sent_counts
# 0                               Here is our forecast          606
# 1  Traveling to have a business meeting takes the...          606
# 2                     test successful.  way to go!!!          606
# 3  Randy,\n\n Can you send me a schedule of the s...          606
# 4                  Let's shoot for Tuesday at 11:45.          606

# %%
# generate sample for review of gender accuracy
gender_sample = df_gender[['m_from', 'name', 'gender']].sample(n=100, random_state=1)

# %%
gender_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 92710 to 11330
# Data columns (total 3 columns):
# m_from    100 non-null object
# name      96 non-null object
# gender    96 non-null object
# dtypes: object(3)
# memory usage: 3.1+ KB

# %%
gender_sample[0:50]
# Out:
#                                 m_from      name gender
# 92710           gerald.nemec@enron.com    gerald    boy
# 58807     ravi.thuraisingham@enron.com      ravi    boy
# 21             phillip.allen@enron.com   phillip    boy
# 32597           garth.ripton@enron.com     garth   girl
# 115601       richard.shapiro@enron.com   richard    boy
# 56615             griff.gray@enron.com      mary   girl
# 136163            pete.davis@enron.com      pete    boy
# 60112      tanya.tamarchenko@enron.com     tanya   girl
# 42969        bruce.lundstrom@enron.com     bruce    boy
# 80150               kay.mann@enron.com       kay   girl
# 11731               rick.buy@enron.com      rick    boy
# 100403       benjamin.rogers@enron.com  benjamin    boy
# 135131            mark.whitt@enron.com      mark    boy
# 29593          chris.dorland@enron.com     chris    boy
# 112699         cheryl.nelson@enron.com    cheryl   girl
# 42461             pete.davis@enron.com      pete    boy
# 122699        fletcher.sturm@enron.com  fletcher    boy
# 128880              m..tholt@enron.com      jane   girl
# 86071              ryan.watt@enron.com      ryan    boy
# 15804              e..carter@enron.com     karen   girl
# 32382            mike.abbott@enron.com      mike    boy
# 26289             pete.davis@enron.com      pete    boy
# 8966    administration.enron@enron.com       NaN    NaN
# 25238          jeff.dasovich@enron.com      jeff    boy
# 9656             jo.williams@enron.com        jo   girl
# 128525            jane.tholt@enron.com      jane   girl
# 62762            steven.kean@enron.com    steven    boy
# 353            phillip.allen@enron.com   phillip    boy
# 104544       richard.sanders@enron.com   richard    boy
# 121161            d..steffes@enron.com     james    boy
# 107645           susan.scott@enron.com     susan   girl
# 129253        barry.tycholiz@enron.com     barry    boy
# 5348              jay.blaine@enron.com       jay    boy
# 29305    announcements.enron@enron.com       NaN    NaN
# 88998        russell.diamond@enron.com   russell    boy
# 81411               kay.mann@enron.com       kay   girl
# 47477       sandra.mcnichols@enron.com    sandra   girl
# 65803           holly.keiser@enron.com     holly   girl
# 42404    enron.announcements@enron.com       NaN    NaN
# 111455           carol.clair@enron.com     carol   girl
# 54545             tana.jones@enron.com      tana   girl
# 88108           patrice.mims@enron.com   patrice    boy
# 7245          lisa.petruszka@enron.com      lisa   girl
# 134909              w..white@enron.com    stacey   girl
# 6254               ted.bland@enron.com       ted    boy
# 99233             mike.smith@enron.com      mike    boy
# 86584       errol.mclaughlin@enron.com     errol    boy
# 9361           john.buchanan@enron.com      john    boy
# 45641           l..bouillion@enron.com     james    boy
# 91343           gerald.nemec@enron.com    gerald    boy

# %%
gender_sample[50:]
# Out:
#                               m_from        name gender
# 21245          alan.comnes@enron.com        alan    boy
# 2471           john.arnold@enron.com        john    boy
# 71390       wilma.williams@enron.com       wilma   girl
# 38547        chris.germany@enron.com       chris    boy
# 48075               m.hall@enron.com         bob    boy
# 47889       alan.aronowitz@enron.com        alan    boy
# 64681   jacqueline.richard@enron.com  jacqueline   girl
# 30764      yvette.connevey@enron.com      yvette   girl
# 11199           lynn.blair@enron.com        lynn   girl
# 22363     gavin.dillingham@enron.com       gavin    boy
# 117227          mary.clark@enron.com        mary   girl
# 115262     linda.robertson@enron.com       linda   girl
# 74434           pete.davis@enron.com        pete    boy
# 115733        lara.leibman@enron.com        lara   girl
# 114121    jeffrey.shankman@enron.com     jeffrey    boy
# 131582            v.weldon@enron.com     charles    boy
# 9336        joni.bollinger@enron.com        joni   girl
# 86450     errol.mclaughlin@enron.com       errol    boy
# 49571          kevin.hyatt@enron.com       kevin    boy
# 129541         dave.fuller@enron.com        dave    boy
# 111072           mary.cook@enron.com        mary   girl
# 120011          susan.mara@enron.com       susan   girl
# 66260       joseph.deffner@enron.com      joseph    boy
# 114745         a..shankman@enron.com     jeffrey    boy
# 65300           kam.keiser@enron.com         kam    boy
# 132215          liz.taylor@enron.com         liz   girl
# 39550         darron.giron@enron.com      darron    boy
# 58949    tanya.tamarchenko@enron.com       tanya   girl
# 9807            no.address@enron.com         NaN    NaN
# 120223     lynnette.barnes@enron.com    lynnette   girl
# 61485           j.kaminski@enron.com       vince    boy
# 121974       chris.stokley@enron.com       chris    boy
# 17500          eric.groves@enron.com        eric    boy
# 15877     monika.causholli@enron.com      monika   girl
# 88065           pete.davis@enron.com        pete    boy
# 110603     sara.shackleton@enron.com        sara   girl
# 90456       neil.leininger@enron.com        neil    boy
# 76988         phillip.love@enron.com     phillip    boy
# 127149       samantha.boyd@enron.com    samantha   girl
# 29630        chris.dorland@enron.com       chris    boy
# 64095        stephen.burns@enron.com     stephen    boy
# 104096    holden.salisbury@enron.com      holden    boy
# 44362          e..haedicke@enron.com        mark    boy
# 132293         w..delainey@enron.com       david    boy
# 92286        gloria.ogenyi@enron.com      gloria   girl
# 45858         rod.hayslett@enron.com         rod    boy
# 13220       larry.campbell@enron.com       larry    boy
# 77364           c..gossett@enron.com     jeffrey    boy
# 25016        jeff.dasovich@enron.com        jeff    boy
# 11330           lynn.blair@enron.com        lynn   girl
